# %%
import json
import pandas as pd
import pymongo

# %%
# Define the path to your JSON file
json_file_path = 'C:/Users/santh/Desktop/Capstone Projects/New folder/PROJECTS/airbnb_analysis/data/sample_airbnb.json'

# Open and load the JSON file
with open(json_file_path, 'r', encoding='utf-8') as data:
    json_data = json.load(data)

# Display the loaded JSON data
# json_data

# %%
df_sample = pd.DataFrame(json_data)
df_sample
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://Santhi:santhikichu@cluster0.jwz3noh.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client['Airbnb_Analysis']
collection = db["data"]

# Converting DataFrame to a list of dictionaries
data_to_insert = df_sample.to_dict(orient='records')

# Inserting the documents into the collection
result = collection.insert_many(data_to_insert)
print("Documents Uploaded Successfully")
# Out:
# Documents Uploaded Successfully

# %%
df_sample.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# security_deposit         2084
# cleaning_fee             1531
# ...

# %%
#null values present in :
        
    # first_review          
    # last_review   
    # bedrooms                    
    # beds 
    #vbathrooms   
    # security_deposit        
    # cleaning_fee    
    # weekly_price            
    # monthly_price         
    # reviews_per_month

# %%
df_sample['first_review'].fillna(0,inplace = True)
df_sample['last_review'].fillna(0,inplace = True)
df_sample['bedrooms'].fillna(0,inplace = True)
df_sample['beds'].fillna(0,inplace = True)
df_sample['bathrooms'].fillna(0,inplace = True)
df_sample['security_deposit'].fillna(0,inplace = True)
df_sample['cleaning_fee'].fillna(0,inplace = True)
df_sample['weekly_price'].fillna(0,inplace = True)
df_sample['monthly_price'].fillna(0,inplace = True)
df_sample['reviews_per_month'].fillna(0,inplace = True)
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_20596\77668252.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sample['first_review'].fillna(0,inplace = True)
# C:\Users\santh\AppData\Local\Temp\ipykernel_20596\77668252.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_sample.isnull().sum()
# Out:
# _id                      0
# listing_url              0
# name                     0
# summary                  0
# space                    0
# description              0
# neighborhood_overview    0
# notes                    0
# transit                  0
# access                   0
# interaction              0
# house_rules              0
# property_type            0
# room_type                0
# bed_type                 0
# minimum_nights           0
# maximum_nights           0
# cancellation_policy      0
# last_scraped             0
# calendar_last_scraped    0
# first_review             0
# last_review              0
# accommodates             0
# bedrooms                 0
# beds                     0
# number_of_reviews        0
# bathrooms                0
# amenities                0
# price                    0
# security_deposit         0
# cleaning_fee             0
# extra_people             0
# guests_included          0
# images                   0
# ...

# %%
df_sample.dtypes
# Out:
# _id                       object
# listing_url               object
# name                      object
# summary                   object
# space                     object
# description               object
# neighborhood_overview     object
# notes                     object
# transit                   object
# access                    object
# interaction               object
# house_rules               object
# property_type             object
# room_type                 object
# bed_type                  object
# minimum_nights            object
# maximum_nights            object
# cancellation_policy       object
# last_scraped              object
# calendar_last_scraped     object
# first_review              object
# last_review               object
# accommodates               int64
# bedrooms                 float64
# beds                     float64
# number_of_reviews          int64
# bathrooms                float64
# amenities                 object
# ...

# %%
#change the data types

# %%
df_sample['minimum_nights'] = df_sample['minimum_nights'].astype(int)
df_sample['maximum_nights'] = df_sample['maximum_nights'].astype(int)
df_sample['bedrooms'] = df_sample['bedrooms'].astype(int)
df_sample['beds'] = df_sample['beds'].astype(int)
df_sample['bathrooms'] = df_sample['bathrooms'].astype(int)
df_sample['price'] = df_sample['price'].astype(str).astype(float).astype(int)
df_sample['cleaning_fee'] = df_sample['cleaning_fee'].astype(int)
df_sample['extra_people'] = df_sample['extra_people'].astype(int)
df_sample['guests_included'] = df_sample['guests_included'].astype(int)
df_sample['weekly_price'] = df_sample['weekly_price'].astype(int)
df_sample['monthly_price'] = df_sample['monthly_price'].astype(int)
df_sample['reviews_per_month'] = df_sample['reviews_per_month'].astype(int)

# %%
df_sample.dtypes
# Out:
# _id                       object
# listing_url               object
# name                      object
# summary                   object
# space                     object
# description               object
# neighborhood_overview     object
# notes                     object
# transit                   object
# access                    object
# interaction               object
# house_rules               object
# property_type             object
# room_type                 object
# bed_type                  object
# minimum_nights             int32
# maximum_nights             int32
# cancellation_policy       object
# last_scraped              object
# calendar_last_scraped     object
# first_review              object
# last_review               object
# accommodates               int64
# bedrooms                   int32
# beds                       int32
# number_of_reviews          int64
# bathrooms                  int32
# amenities                 object
# ...

# %%
# Host details

# %%
# Fetching documents from the collection with the specified projection
host = []
for i in collection.find({}, {
    '_id': 1,
    'host': 1,
}):
    host.append(i)

# Creating a DataFrame from the fetched documents
df_host = pd.DataFrame(host)

# Display the DataFrame
df_host
# Out:
#            _id                                               host
# 0      1003530  {'host_id': '454250', 'host_url': 'https://www...
# 1     10133554  {'host_id': '52004703', 'host_url': 'https://w...
# 2     10059872  {'host_id': '51624384', 'host_url': 'https://w...
# 3     10084023  {'host_id': '51744313', 'host_url': 'https://w...
# 4     10091713  {'host_id': '13764143', 'host_url': 'https://w...
# ...        ...                                                ...
# 5550   9985696  {'host_id': '51303748', 'host_url': 'https://w...
# 5551   9993190  {'host_id': '51013381', 'host_url': 'https://w...
# 5552   9887054  {'host_id': '31386255', 'host_url': 'https://w...
# 5553   9907907  {'host_id': '47615848', 'host_url': 'https://w...
# 5554   9936016  {'host_id': '47092481', 'host_url': 'https://w...
#
# [5555 rows x 2 columns]

# %%
host_columns= {'_id':[],'host_id':[], 'host_url':[], 'host_name':[], 'host_location':[],"host_response_time":[], 'host_thumbnail_url':[], 'host_picture_url':[], 'host_neighbourhood':[], 'host_response_rate':[], 'host_is_superhost':[], 'host_has_profile_pic':[], 'host_identity_verified':[], 'host_listings_count':[], 'host_total_listings_count':[], 'host_verifications':[]}

for i in df_host["_id"]:
    host_columns["_id"].append(i)
for i in df_host["host"]:
    host_columns["host_id"].append(i["host_id"])
    host_columns["host_url"].append(i["host_url"])
    host_columns["host_name"].append(i["host_name"])
    host_columns["host_location"].append(i["host_location"])
    host_columns["host_response_time"].append(i.get("host_response_time"))
    host_columns["host_thumbnail_url"].append(i["host_thumbnail_url"])
    host_columns["host_picture_url"].append(i["host_picture_url"])
    host_columns["host_neighbourhood"].append(i["host_neighbourhood"])
    host_columns["host_response_rate"].append(i.get("host_response_rate"))
    host_columns["host_is_superhost"].append(i["host_is_superhost"])
    host_columns["host_has_profile_pic"].append(i["host_has_profile_pic"])
    host_columns["host_identity_verified"].append(i["host_identity_verified"])
    host_columns["host_listings_count"].append(i["host_listings_count"])
    host_columns["host_total_listings_count"].append(i["host_total_listings_count"])
    host_columns["host_verifications"].append(i["host_verifications"])

# %%
df_host= pd.DataFrame(host_columns)
df_host.head(5)
# Out:
#         _id   host_id                                    host_url  \
# 0   1003530    454250    https://www.airbnb.com/users/show/454250
# 1  10133554  52004703  https://www.airbnb.com/users/show/52004703
# 2  10059872  51624384  https://www.airbnb.com/users/show/51624384
# 3  10084023  51744313  https://www.airbnb.com/users/show/51744313
# 4  10091713  13764143  https://www.airbnb.com/users/show/13764143
#
#      host_name                      host_location  host_response_time  \
# 0        Greta  New York, New York, United States      within an hour
# 1  Mehmet Emin         Istanbul, İstanbul, Turkey  within a few hours
# 2     Giovanni               Hong Kong, Hong Kong                None
# 3           Yi                      United States      within an hour
# 4          Ben         New South Wales, Australia                None
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/f1022be4-e...
# ...

# %%
df_host.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
df_host["host_response_time"].fillna("Not Specified",inplace= True)
df_host["host_response_rate"].fillna("Not Specified",inplace= True)
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_20596\3549105767.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_host["host_response_time"].fillna("Not Specified",inplace= True)
# C:\Users\santh\AppData\Local\Temp\ipykernel_20596\3549105767.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# host_neighbourhood have more empty values ('')

list_hs_neighbr= []
for index,row in df_host.iterrows():
    if row["host_neighbourhood"] =='':
        list_hs_neighbr.append(index)

# %%
len(list_hs_neighbr)
# Out:
# 1923

# %%
# "host_neighbourhood" have a "1923" empty values ('')
# so we want to replace thet empty values
df_host["host_neighbourhood"]= df_host["host_neighbourhood"].replace({'':"Not Specified"})

# %%
df_host.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host
# Out:
#            _id   host_id                                    host_url  \
# 0      1003530    454250    https://www.airbnb.com/users/show/454250
# 1     10133554  52004703  https://www.airbnb.com/users/show/52004703
# 2     10059872  51624384  https://www.airbnb.com/users/show/51624384
# 3     10084023  51744313  https://www.airbnb.com/users/show/51744313
# 4     10091713  13764143  https://www.airbnb.com/users/show/13764143
# ...        ...       ...                                         ...
# 5550   9985696  51303748  https://www.airbnb.com/users/show/51303748
# 5551   9993190  51013381  https://www.airbnb.com/users/show/51013381
# 5552   9887054  31386255  https://www.airbnb.com/users/show/31386255
# 5553   9907907  47615848  https://www.airbnb.com/users/show/47615848
# 5554   9936016  47092481  https://www.airbnb.com/users/show/47092481
#
#            host_name                            host_location  \
# 0              Greta        New York, New York, United States
# ...

# %%
#adress details

# %%
address= []
for i in collection.find({}, {"_id":1, "address":1}):
    address.append(i)

# %%
df_address= pd.DataFrame(address)

# %%
address_columns= {'_id':[], 'street':[], 'suburb':[], 'government_area':[], 'market':[], 'country':[],
                   'country_code':[], 'location_type':[], "longitude":[], "latitude":[],
                    "is_location_exact":[]}

for i in df_address["_id"]:
    address_columns["_id"].append(i)

for i in df_address["address"]:
    address_columns["street"].append(i["street"])
    address_columns["suburb"].append(i["suburb"])
    address_columns["government_area"].append(i["government_area"])
    address_columns["market"].append(i["market"])
    address_columns["country"].append(i["country"])
    address_columns["country_code"].append(i["country_code"])
    address_columns["location_type"].append(i["location"]["type"])
    address_columns["longitude"].append(i["location"]["coordinates"][0])
    address_columns["latitude"].append(i["location"]["coordinates"][1])
    address_columns["is_location_exact"].append(i["location"]["is_location_exact"])

# %%
df_address= pd.DataFrame(address_columns)
df_address.head(5)
# Out:
#         _id                                  street  \
# 0   1003530             New York, NY, United States
# 1  10133554                Fatih , İstanbul, Turkey
# 2  10059872  Hong Kong, Hong Kong Island, Hong Kong
# 3  10084023               Hong Kong , 九龍, Hong Kong
# 4  10091713             Surry Hills, NSW, Australia
#
#                        suburb    government_area     market        country  \
# 0                   Manhattan    Upper West Side   New York  United States
# 1                       Fatih              Fatih   Istanbul         Turkey
# 2  Central & Western District  Central & Western  Hong Kong      Hong Kong
# 3       Sham Shui Po District       Sham Shui Po  Hong Kong      Hong Kong
# 4                Darlinghurst             Sydney     Sydney      Australia
#
#   country_code location_type  longitude  latitude  is_location_exact
# 0           US         Point  -73.96523  40.79962              False
# ...

# %%
df_address.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
df_address.isna().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
# Checking the empty values ('') for all features

#for i in df_address_1.columns:
id_e=[]
stre_e=[]
suburb_e=[]
gov_e=[]
mark_e=[]
cntry_e=[]
cntry_co_e=[]
loc_ty_e=[]
long_e=[]
lat_e=[]
is_loc_tr_e=[]
for index,row in df_address.iterrows():
    if row["_id"] == '':
        id_e.append(index)

    if row["street"] == '':
        stre_e.append(index)
        
    if row["suburb"] == '':
        suburb_e.append(index)

    if row["government_area"] == '':
        gov_e.append(index)

    if row["market"] == '':
        mark_e.append(index)

    if row["country"] == '':
        cntry_e.append(index)
    
    if row["country_code"] == '':
        cntry_co_e.append(index)

    if row["location_type"] == '':
        loc_ty_e.append(index) 

    if row["longitude"] == '':
        long_e.append(index)

    if row["latitude"] == '':
        lat_e.append(index)

    if row["is_location_exact"] == '':
        is_loc_tr_e.append(index)

# %%
empty_columns=[id_e,stre_e,suburb_e,gov_e,mark_e,cntry_e,cntry_co_e,loc_ty_e,long_e,lat_e,is_loc_tr_e]
for i in empty_columns:
    print(len(i))
# Out:
# 0
# 0
# 887
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# "suburb" and "market" have a empty values

df_address["suburb"]= df_address["suburb"].replace({'':"Not Specified"})
df_address["market"]= df_address["market"].replace({'':"Not Specified"})

# %%
#availability

# %%
availability= []
for i in collection.find({}, {"_id":1, "availability":1}):
    availability.append(i)

# %%
df_available= pd.DataFrame(availability)
df_available
# Out:
#            _id                                       availability
# 0      1003530  {'availability_30': 0, 'availability_60': 0, '...
# 1     10133554  {'availability_30': 30, 'availability_60': 60,...
# 2     10059872  {'availability_30': 0, 'availability_60': 0, '...
# 3     10084023  {'availability_30': 14, 'availability_60': 24,...
# 4     10091713  {'availability_30': 0, 'availability_60': 0, '...
# ...        ...                                                ...
# 5550   9985696  {'availability_30': 30, 'availability_60': 60,...
# 5551   9993190  {'availability_30': 0, 'availability_60': 8, '...
# 5552   9887054  {'availability_30': 18, 'availability_60': 48,...
# 5553   9907907  {'availability_30': 0, 'availability_60': 0, '...
# 5554   9936016  {'availability_30': 0, 'availability_60': 0, '...
#
# [5555 rows x 2 columns]

# %%
available_columns= {'_id':[], 'availability_30':[], 'availability_60':[], 'availability_90':[], 'availability_365':[]}

for i in df_available["_id"]:
    available_columns["_id"].append(i)

for i in df_available["availability"]:
    available_columns["availability_30"].append(i["availability_30"])
    available_columns["availability_60"].append(i["availability_60"])
    available_columns["availability_90"].append(i["availability_90"])
    available_columns["availability_365"].append(i["availability_365"])

# %%
df_available= pd.DataFrame(available_columns)
df_available
# Out:
#            _id  availability_30  availability_60  availability_90  \
# 0      1003530                0                0                0
# 1     10133554               30               60               90
# 2     10059872                0                0                0
# 3     10084023               14               24               40
# 4     10091713                0                0                0
# ...        ...              ...              ...              ...
# 5550   9985696               30               60               90
# 5551   9993190                0                8               31
# 5552   9887054               18               48               78
# 5553   9907907                0                0                0
# 5554   9936016                0                0                0
#
#       availability_365
# 0                   93
# 1                  365
# 2                    0
# 3                  220
# 4                    0
# ...                ...
# ...

# %%
df_available.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_available.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %%
#Amenities collection

# %%
amenities= []
for i in collection.find({},{"_id":1, "amenities":1}):
    amenities.append(i)

# %%
df_amenities= pd.DataFrame(amenities)

# %%
def sort_amenities(x):
    if isinstance(x, list):
        x.sort()
    return x

df_amenities["amenities"] = df_amenities["amenities"].apply(sort_amenities)

# %%
df_amenities
# Out:
#            _id                                          amenities
# 0      1003530  [Air conditioning, Buzzer/wireless intercom, D...
# 1     10133554  [Air conditioning, Building staff, Dryer, Esse...
# 2     10059872  [24-hour check-in, Air conditioning, Doorman, ...
# 3     10084023  [Air conditioning, Dishes and silverware, Elev...
# 4     10091713  [Bed linens, Dryer, Elevator, Essentials, Ethe...
# ...        ...                                                ...
# 5550   9985696  [Buzzer/wireless intercom, Cable TV, Dryer, Es...
# 5551   9993190  [Air conditioning, Dryer, Essentials, Family/k...
# 5552   9887054  [24-hour check-in, Air conditioning, Elevator,...
# 5553   9907907  [Dryer, Essentials, Hangers, Internet, Kitchen...
# 5554   9936016  [Air conditioning, Buzzer/wireless intercom, C...
#
# [5555 rows x 2 columns]

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %%
# add all dataframes into one 

df_final = pd.merge(df_sample, df_host, on="_id")
df_final = pd.merge(df_final, df_address, on="_id")
df_final = pd.merge(df_final, df_available, on="_id")
df_final = pd.merge(df_final, df_amenities, on="_id")

# %%
df_final
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# ...

# %%
#save the file in csv format
df_final.to_csv("airbnb_sample_data.csv",index = False)

# %%
df_final = pd.read_csv("C:/Users/santh/Desktop/Capstone Projects/New folder/PROJECTS/airbnb_analysis/airbnb_sample_data.csv")
df_final
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# ...
